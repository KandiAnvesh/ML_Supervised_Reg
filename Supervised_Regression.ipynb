# %%
import pandas as pd

# %%
df = pd.read_csv('greendestination.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.drop(['DailyRate','Attrition','DailyRate','EducationField','EmployeeCount','EmployeeNumber','HourlyRate','MonthlyRate','Over18','RelationshipSatisfaction','StandardHours','TrainingTimesLastYear'], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales                 1
# 1   49  Travel_Frequently  Research & Development                 8
#
#    Education  EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0          2                        2  Female               3         2
# 1          1                        3    Male               2         2
#
#               JobRole  ...  OverTime PercentSalaryHike  PerformanceRating  \
# 0     Sales Executive  ...       Yes                11                  3
# 1  Research Scientist  ...        No                23                  4
#
#    StockOptionLevel TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 0                 0                 8                1               6
# 1                 1                10                3              10
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
df.Department.value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df.OverTime.head(2)
# Out:
# 0    Yes
# 1     No
# Name: OverTime, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['OverTime'] = label_encoder.fit_transform(df['OverTime'])

# %%
df.OverTime.head(2)
# Out:
# 0    1
# 1    0
# Name: OverTime, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'StockOptionLevel', 'TotalWorkingYears',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
#df['Attrition'] = pd.factorize(df['Attrition'])[0]
df['BusinessTravel'] = pd.factorize(df['BusinessTravel'])[0]
df['Department'] = pd.factorize(df['Department'])[0]
df['Gender'] = pd.factorize(df['Gender'])[0]
df['JobRole'] = pd.factorize(df['JobRole'])[0]
df['MaritalStatus'] = pd.factorize(df['MaritalStatus'])[0]

# %%
df.head(2)
# Out:
#    Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   41               0           0                 1          2
# 1   49               1           1                 8          1
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobRole  ...  \
# 0                        2       0               3         2        0  ...
# 1                        3       1               2         2        1  ...
#
#    OverTime  PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# 0         1                 11                  3                 0
# 1         0                 23                  4                 1
#
#    TotalWorkingYears  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                  8                1               6                   4
# 1                 10                3              10                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   BusinessTravel           1470 non-null   int64
#  2   Department               1470 non-null   int64
#  3   DistanceFromHome         1470 non-null   int64
#  4   Education                1470 non-null   int64
#  5   EnvironmentSatisfaction  1470 non-null   int64
#  6   Gender                   1470 non-null   int64
#  7   JobInvolvement           1470 non-null   int64
#  8   JobLevel                 1470 non-null   int64
#  9   JobRole                  1470 non-null   int64
#  10  JobSatisfaction          1470 non-null   int64
#  11  MaritalStatus            1470 non-null   int64
#  12  MonthlyIncome            1470 non-null   int64
#  13  NumCompaniesWorked       1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  BusinessTravel   Department  DistanceFromHome  \
# count  1470.000000     1470.000000  1470.000000       1470.000000
# mean     36.923810        0.392517     0.739456          9.192517
# std       9.135373        0.665455     0.527792          8.106864
# min      18.000000        0.000000     0.000000          1.000000
# 25%      30.000000        0.000000     0.000000          2.000000
# 50%      36.000000        0.000000     1.000000          7.000000
# 75%      43.000000        1.000000     1.000000         14.000000
# max      60.000000        2.000000     2.000000         29.000000
#
#          Education  EnvironmentSatisfaction       Gender  JobInvolvement  \
# count  1470.000000              1470.000000  1470.000000     1470.000000
# mean      2.912925                 2.721769     0.600000        2.729932
# std       1.024165                 1.093082     0.490065        0.711561
# min       1.000000                 1.000000     0.000000        1.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   BusinessTravel           1470 non-null   int64
#  2   Department               1470 non-null   int64
#  3   DistanceFromHome         1470 non-null   int64
#  4   Education                1470 non-null   int64
#  5   EnvironmentSatisfaction  1470 non-null   int64
#  6   Gender                   1470 non-null   int64
#  7   JobInvolvement           1470 non-null   int64
#  8   JobLevel                 1470 non-null   int64
#  9   JobRole                  1470 non-null   int64
#  10  JobSatisfaction          1470 non-null   int64
#  11  MaritalStatus            1470 non-null   int64
#  12  MonthlyIncome            1470 non-null   int64
#  13  NumCompaniesWorked       1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'StockOptionLevel', 'TotalWorkingYears',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
histograms = df.hist(figsize=(10,10))

# %%
import numpy as np
df['DistanceFromHome'] = np.log1p(df['DistanceFromHome']) #Right sckewed to Normalized
df['YearsWithCurrManager'] = np.log1p(df['YearsWithCurrManager'])
#df['MonthlyIncome'] = np.log1p(df['MonthlyIncome'].max() - df['MonthlyIncome'])    #Left sckewed to Normalized
#df['NumCompaniesWorked'] = np.log1p(df['NumCompaniesWorked'])
df['PercentSalaryHike'] = np.log1p(df['PercentSalaryHike'])
#df['TotalWorkingYears'] = np.log1p(df['TotalWorkingYears'])
df['YearsAtCompany'] = np.log1p(df['YearsAtCompany'])
#df['YearsInCurrentRole'] = np.log1p(df['YearsInCurrentRole'])

# %%
histograms = df.hist(figsize=(10,10))

# %%
x = df.drop('MonthlyIncome', axis=1)
y = df.MonthlyIncome

# %%
print(x.columns)
# Out:
# Index(['Age', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'StockOptionLevel', 'TotalWorkingYears', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (1470, 23)
# (1470,)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X = scale.fit_transform(x)

# %%
X[0]
# Out:
# array([ 0.4463504 , -0.59004834, -1.40151234, -1.50534967, -0.89168825,
#        -0.66053067, -1.22474487,  0.37967213, -0.05778755, -1.09898378,
#         1.15325359, -1.23682046,  2.12513592,  1.59174553, -1.29267741,
#        -0.42623002, -0.93201439, -0.42164246, -2.49382042,  0.17734444,
#        -0.0632959 , -0.67914568,  0.54799589])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=36)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1102, 23)
# (1102,)
# (368, 23)
# (368,)

# %%
from sklearn import neighbors
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

# %%
model = neighbors.KNeighborsRegressor(n_neighbors = 11)
model.fit(X_train, y_train)  #fit the model
pred=model.predict(X_test) #make prediction on test set

# %%
error = sqrt(mean_squared_error(y_test,pred))
print('RMSE value is:', error)
# Out:
# RMSE value is: 2162.585962412992

# %%
error_rate = []
for i in range(1,21):
    knn = neighbors.KNeighborsRegressor(n_neighbors=i)
    knn.fit(X_train,y_train)
    y_pred = knn.predict(X_test)
    error_rate.append(sqrt(mean_squared_error(y_test,y_pred))) #calculate rmse

plt.figure(figsize=(10,6))
plt.plot(range(1,21),error_rate)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
'''
RMSE and R2
'''
# Out:
# '\nRMSE and R2\n'

# %%
#####################################################################################################################

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,accuracy_score
DT = DecisionTreeRegressor()
DTR = DT.fit(X_train,y_train)
y_pred = DTR.predict(X_test)

# %%
print('R2 score is: ',r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score is:  0.9163003892729226
# Mean Absolute Error: 1013.3152173913044
# Mean Squared Error: 2003125.9347826086
# Root Mean Squared Error: 1415.3183157094409

# %%
###########################################################################################################################

# %%
from sklearn.linear_model import LinearRegression

LR = LinearRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)

# %%
print('R2 score is: ',r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score is:  0.9251159716243098
# Mean Absolute Error: 1019.9604084569668
# Mean Squared Error: 1792148.5899075405
# Root Mean Squared Error: 1338.711540963004

# %%
####################################################################################################################################

# %%
from sklearn.svm import SVR

svr = SVR(kernel = 'linear',gamma=1)
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)

# %%
print('R2 score is: ',r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score is:  0.40541239765013004
# Mean Absolute Error: 2527.6943250877594
# Mean Squared Error: 14229861.243332231
# Root Mean Squared Error: 3772.2488310465724

# %%
###################################################################################################################################

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
print('R2 score is: ',r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score is:  0.9587030422389884
# Mean Absolute Error: 746.6647092391305
# Mean Squared Error: 988332.0412139375
# Root Mean Squared Error: 994.1489029385575

# %%
import pickle

# Save the model to a file
with open('rf_reg.pkl', 'wb') as file:
    pickle.dump(rf, file)

print("Model saved as rf_reg.pkl")
# Out:
# Model saved as rf_reg.pkl

# %%
#################################################################################################################################

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=1.0, max_depth=3)
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)

# %%
print('R2 score is: ',r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score is:  0.9165012223021497
# Mean Absolute Error: 1087.302352806779
# Mean Squared Error: 1998319.5342998446
# Root Mean Squared Error: 1413.6193031717714

# %%
###################################################################################################################################

# %%
import xgboost as xgb
xgboost = xgb.XGBRegressor()
xgboost.fit(X_train, y_train)
y_pred = xgboost.predict(X_test)

# %%
print('R2 score is: ',r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score is:  0.9497438073158264
# Mean Absolute Error: 839.001708984375
# Mean Squared Error: 1202747.25
# Root Mean Squared Error: 1096.6983404747177
